# %% [markdown]
# # Data Preprocessing-Before Building Machine learnig model

# %% [markdown]
# #STEPS of preprocessing of data\
# step:1]- Import neccessary library\
# step:2]- Read Dataset\
# step:3]- sanity check of data\
# step:4]- Exploratory Data Analysis(EDA)

# %% [markdown]
# ### step:1]- Import neccessary library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### step:2]- Read Dataset

# %%
df = pd.read_csv(r"E:\DEPI\Food Project\1 EDA & Cleaning (Python)\wfp_food_prices_egy.csv")

# %%
#head
df.head()
# Out:
#          date      admin1      admin2            market         market_id  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name  #loc+market+code
# 1  2010-08-15         NaN         NaN  National Average               226
# 2  2010-08-15         NaN         NaN  National Average               226
# 3  2010-08-15         NaN         NaN  National Average               226
# 4  2010-08-15         NaN         NaN  National Average               226
#
#    latitude longitude            category    commodity commodity_id  \
# 0  #geo+lat  #geo+lon          #item+type   #item+name   #item+code
# 1       NaN       NaN  cereals and tubers        Pasta          112
# 2       NaN       NaN  cereals and tubers     Potatoes           83
# 3       NaN       NaN  cereals and tubers         Rice           52
# 4       NaN       NaN  cereals and tubers  Wheat flour           58
#
#          unit         priceflag         pricetype        currency   price  \
# 0  #item+unit  #item+price+flag  #item+price+type  #currency+code  #value
# 1          KG            actual            Retail             EGP     4.7
# 2          KG            actual            Retail             EGP    1.81
# 3          KG            actual            Retail             EGP    3.98
# 4          KG            actual            Retail             EGP    3.44
#
#      usdprice
# 0  #value+usd
# 1        0.82
# 2        0.32
# 3         0.7
# 4         0.6

# %%
#tail
df.tail()
# Out:
#             date admin1 admin2                    market market_id latitude  \
# 2486  2025-04-15  Cairo  Abdin  Cairo (national average)     10254    30.05
# 2487  2025-04-15  Cairo  Abdin  Cairo (national average)     10254    30.05
# 2488  2025-04-15  Cairo  Abdin  Cairo (national average)     10254    30.05
# 2489  2025-04-15  Cairo  Abdin  Cairo (national average)     10254    30.05
# 2490  2025-04-15  Cairo  Abdin  Cairo (national average)     10254    30.05
#
#      longitude               category                    commodity  \
# 2486     31.24     cereals and tubers  Wheat flour (unpacked, 72%)
# 2487     31.24    meat, fish and eggs               Fish (tilapia)
# 2488     31.24    meat, fish and eggs         Meat (chicken, farm)
# 2489     31.24        pulses and nuts                      Lentils
# 2490     31.24  vegetables and fruits     Cucumbers (medium sized)
#
#      commodity_id unit priceflag pricetype currency  price usdprice
# 2486         1302   KG    actual    Retail      EGP  22.23     0.44
# 2487          405   KG    actual    Retail      EGP  94.27     1.85
# 2488         1303   KG    actual    Retail      EGP  99.36     1.95
# 2489          108   KG    actual    Retail      EGP  62.46     1.23
# 2490         1299   KG    actual    Retail      EGP  20.49      0.4

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude',
#        'longitude', 'category', 'commodity', 'commodity_id', 'unit',
#        'priceflag', 'pricetype', 'currency', 'price', 'usdprice'],
#       dtype='object')

# %%
df.drop(df.index[0], inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#          date admin1 admin2            market market_id latitude longitude  \
# 0  2010-08-15    NaN    NaN  National Average       226      NaN       NaN
# 1  2010-08-15    NaN    NaN  National Average       226      NaN       NaN
# 2  2010-08-15    NaN    NaN  National Average       226      NaN       NaN
# 3  2010-08-15    NaN    NaN  National Average       226      NaN       NaN
# 4  2010-08-15    NaN    NaN  National Average       226      NaN       NaN
#
#               category    commodity commodity_id unit priceflag pricetype  \
# 0   cereals and tubers        Pasta          112   KG    actual    Retail
# 1   cereals and tubers     Potatoes           83   KG    actual    Retail
# 2   cereals and tubers         Rice           52   KG    actual    Retail
# 3   cereals and tubers  Wheat flour           58   KG    actual    Retail
# 4  meat, fish and eggs  Meat (beef)          141   KG    actual    Retail
#
#   currency  price usdprice
# 0      EGP    4.7     0.82
# 1      EGP   1.81     0.32
# 2      EGP   3.98      0.7
# 3      EGP   3.44      0.6
# 4      EGP  50.22     8.81

# %% [markdown]
# ### step:3]- sanity check of data

# %%
#shape
df.shape
# Out:
# (2490, 16)

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude',
#        'longitude', 'category', 'commodity', 'commodity_id', 'unit',
#        'priceflag', 'pricetype', 'currency', 'price', 'usdprice'],
#       dtype='object')

# %%
#info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2490 entries, 0 to 2489
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2490 non-null   object
#  1   admin1        512 non-null    object
#  2   admin2        512 non-null    object
#  3   market        2490 non-null   object
#  4   market_id     2490 non-null   object
#  5   latitude      512 non-null    object
#  6   longitude     512 non-null    object
#  7   category      2490 non-null   object
#  8   commodity     2490 non-null   object
#  9   commodity_id  2490 non-null   object
#  10  unit          2490 non-null   object
#  11  priceflag     2490 non-null   object
#  12  pricetype     2490 non-null   object
#  13  currency      2490 non-null   object
#  14  price         2490 non-null   object
#  15  usdprice      2490 non-null   object
# dtypes: object(16)
# memory usage: 311.4+ KB

# %%
#finding missing value
df.isnull().sum()
# Out:
# date               0
# admin1          1978
# admin2          1978
# market             0
# market_id          0
# latitude        1978
# longitude       1978
# category           0
# commodity          0
# commodity_id       0
# unit               0
# priceflag          0
# pricetype          0
# currency           0
# price              0
# usdprice           0
# dtype: int64

# %%
#Percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# date             0.000000
# admin1          79.437751
# admin2          79.437751
# market           0.000000
# market_id        0.000000
# latitude        79.437751
# longitude       79.437751
# category         0.000000
# commodity        0.000000
# commodity_id     0.000000
# unit             0.000000
# priceflag        0.000000
# pricetype        0.000000
# currency         0.000000
# price            0.000000
# usdprice         0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude',
#        'longitude', 'category', 'commodity', 'commodity_id', 'unit',
#        'priceflag', 'pricetype', 'currency', 'price', 'usdprice'],
#       dtype='object')

# %%
print(df['admin1'].unique())
print(df['admin2'].unique())
# Out:
# [nan 'Cairo']
# [nan 'Abdin']

# %%
print(df['priceflag'].unique())
print(df['pricetype'].unique())
print(df['currency'].unique())
# Out:
# ['actual']
# ['Retail']
# ['EGP']

# %%
print(df['market'].unique())
print(df['market_id'].unique())
# Out:
# ['National Average' 'Cairo (national average)']
# ['226' '10254']

# %%
df = df[['date', 'category', 'commodity', 'commodity_id', 'unit',
       'price', 'usdprice']]

# %%
#Percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# date            0.0
# category        0.0
# commodity       0.0
# commodity_id    0.0
# unit            0.0
# price           0.0
# usdprice        0.0
# dtype: float64

# %%
#finding duplicates
df.duplicated().all().sum()
# Out:
# 0

# %%
df['commodity'].unique()
# Out:
# array(['Pasta', 'Potatoes', 'Rice', 'Wheat flour', 'Meat (beef)',
#        'Meat (chicken, frozen)', 'Sugar', 'Ghee (natural)', 'Oil (maize)',
#        'Lentils', 'Onions (red)', 'Tomatoes', 'Ghee (artificial)',
#        'Garlic', 'Onions (white)', 'Beans (fava, dry)', 'Eggs',
#        'Oil (sunflower)', 'Fish (tilapia)', 'Cheese', 'Cheese (picon)',
#        'Milk', 'Oil (mixed)', 'Meat (beef, without bones)',
#        'Wheat flour (unpacked, 72%)', 'Eggs (medium size)',
#        'Cheese (local, processed, Nesto)', 'Oil (cotton)',
#        'Meat (chicken, farm)', 'Cucumbers (medium sized)', 'Milk (fresh)'],
#       dtype=object)

# %%
df['category'].unique()
# Out:
# array(['cereals and tubers', 'meat, fish and eggs', 'miscellaneous food',
#        'oil and fats', 'pulses and nuts', 'vegetables and fruits',
#        'milk and dairy'], dtype=object)

# %%
#identifiying garbage values
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("****"*10)
# Out:
# date
# 2021-02-15    30
# 2021-12-15    30
# 2021-07-15    27
# 2021-10-15    26
# 2022-04-15    26
#               ..
# 2011-03-15     8
# 2023-05-15     8
# 2023-06-15     8
# 2023-03-15     6
# 2025-04-15     6
# Name: count, Length: 176, dtype: int64
# ****************************************
# category
# cereals and tubers       553
# vegetables and fruits    452
# oil and fats             441
# meat, fish and eggs      426
# pulses and nuts          288
# milk and dairy           190
# miscellaneous food       140
# Name: count, dtype: int64
# ****************************************
# commodity
# Lentils                             147
# Tomatoes                            147
# Pasta                               146
# Rice                                143
# Beans (fava, dry)                   141
# Sugar                               140
# Wheat flour                         120
# Meat (chicken, frozen)              115
# Ghee (natural)                      112
# Oil (maize)                         110
# Garlic                              109
# Onions (red)                        109
# Potatoes                            107
# Eggs                                 89
# Oil (mixed)                          66
# Oil (sunflower)                      64
# Meat (beef, without bones)           63
# Cheese (picon)                       60
# Cheese                               59
# Onions (white)                       52
# Ghee (artificial)                    48
# Meat (beef)                          43
# Oil (cotton)                         41
# Cheese (local, processed, Nesto)     40
# Meat (chicken, farm)                 40
# Fish (tilapia)                       39
# Eggs (medium size)                   37
# Wheat flour (unpacked, 72%)          37
# Cucumbers (medium sized)             35
# Milk (fresh)                         29
# Milk                                  2
# Name: count, dtype: int64
# ****************************************
# commodity_id
# 108     147
# 114     147
# 112     146
# 52      143
# 385     141
# 97      140
# 58      120
# 207     115
# 107     112
# 362     110
# 105     109
# 110     109
# 83      107
# 92       89
# 395      66
# 184      64
# 468      63
# 319      60
# 414      59
# 111      52
# 106      48
# 141      43
# 172      41
# 1300     40
# 1303     40
# 405      39
# 1301     37
# 1302     37
# 1299     35
# 758      29
# 81        2
# Name: count, dtype: int64
# ****************************************
# unit
# KG         1981
# 800 G       281
# 8 pcs       100
# Unit         89
# 1 piece      37
# L             2
# Name: count, dtype: int64
# ****************************************
# price
# 23.5      19
# 6.93      19
# 20.5      17
# 7.59      15
# 27.15     14
#           ..
# 27.14      1
# 106.34     1
# 21.86      1
# 42.1       1
# 20.49      1
# Name: count, Length: 1320, dtype: int64
# ****************************************
# usdprice
# 0.62    42
# 0.12    35
# 0.39    34
# 0.63    33
# 0.44    31
#         ..
# 7.98     1
# 6.04     1
# 6        1
# 6.49     1
# 1.02     1
# Name: count, Length: 446, dtype: int64
# ****************************************

# %%
# كود ذكي للكشف عن القيم المشكوك فيها (Garbage Detection)
garbage_report = {}

for col in df.select_dtypes(include="object").columns:
    counts = df[col].value_counts()
    
    # هنطلع القيم اللي اتكررت أقل من 3 مرات (احتمال كبير تكون غلطة إملائية)
    rare_values = counts[counts < 3].index.tolist()
    
    # هنطلع الكلمات اللي فيها رموز مش حروف (زي ? أو #)
    suspicious_chars = [val for val in counts.index if any(char in str(val) for char in ['?', '#', '!', '*'])]
    
    if rare_values or suspicious_chars:
        garbage_report[col] = {
            "Rare Values (Possible Typos)": rare_values,
            "Suspicious Symbols": suspicious_chars
        }

# عرض التقرير
if not garbage_report:
    print("✨ البيانات نظيفة زي الفل مفيش قيم غريبة واضحة!")
else:
    for col, issues in garbage_report.items():
        print(f"🔍 العمود: 【{col}】")
        if issues["Rare Values (Possible Typos)"]:
            print(f"   - قيم نادرة (ممكن تكون غلطات): {issues['Rare Values (Possible Typos)']}")
        if issues["Suspicious Symbols"]:
            print(f"   - رموز مشبوهة: {issues['Suspicious Symbols']}")
        print("-" * 30)
# Out:
# 🔍 العمود: 【commodity】
#    - قيم نادرة (ممكن تكون غلطات): ['Milk']
# ------------------------------
# 🔍 العمود: 【commodity_id】
#    - قيم نادرة (ممكن تكون غلطات): ['81']
# ------------------------------
# 🔍 العمود: 【unit】
#    - قيم نادرة (ممكن تكون غلطات): ['L']
# ------------------------------
# 🔍 العمود: 【price】
#    - قيم نادرة (ممكن تكون غلطات): ['1.18', '14.76', '11.28', '29.56', '16.48', '21.53', '29.98', '25.61', '23.4', '4.21', '14.05', '14.3', '5.8', '5.52', '10.15', '28.96', '30.05', '20.99', '30.6', '25.44', '13.21', '26.94', '27.77', '9.21', '13.65', '28.24', '3.49', '20.32', '30.01', '6.8', '8.63', '7.6', '30.54', '12.13', '2.69', '32.93', '28.51', '6.35', '3.78', '15.3', '9.3', '13.61', '33.75', '22.79', '12.67', '5.7', '23.04', '5.66', '31.28', '20.78', '65', '2.88', '3.13', '12.31', '8.65', '9.04', '47.08', '3.02', '7.06', '32.7', '9.1', '10.02', '4.19', '8.75', '4.96', '28.16', '32.68', '58.43', '5.92', '7.43', '31.9', '27.78', '27.48', '5.51', '10.8', '3.6', '29.32', '5.3', '22.75', '9.2', '135.18', '18.68', '11.11', '19.5', '148.42', '24', '29.49', '7.78', '6.95', '19.32', '8.77', '14.59', '96.1', '2.03', '13.17', '18.46', '9.77', '11.95', '9.68', '26.32', '8.14', '1.73', '19.96', '31.79', '6.6', '31.38', '10.32', '5.79', '14.82', '10.52', '2.04', '20.85', '28.21', '125.87', '33.21', '38.51', '11.63', '8.21', '28.57', '25.42', '12.68', '8.53', '28.18', '24.13', '21.06', '6.61', '7.14', '34.6', '20.68', '9.52', '21.15', '25.74', '14.24', '7.05', '2.27', '7.1', '27.73', '90', '36', '35.47', '17.25', '18.31', '23.34', '13.94', '8.24', '7.55', '107.23', '7.75', '17.5', '36.74', '31.24', '8.52', '24.64', '27.34', '40.6', '21.45', '11.86', '1.82', '8.25', '25.37', '20.39', '13.93', '7.16', '9.71', '1.56', '41.52', '148.55', '4.11', '23.92', '17.14', '8.35', '15.49', '1.61', '8.17', '11.82', '15.67', '26.38', '5.22', '36.5', '12.12', '5.45', '58.3', '12.25', '4.56', '12.1', '5.44', '21.5', '11.19', '38.1', '0.78', '38', '4.09', '13.28', '18.3', '3.81', '13.4', '3.48', '1.96', '40.4', '3.62', '1.4', '5.2', '4.55', '10.7', '5.01', '42.8', '5.57', '10.2', '3.88', '8.1', '12.38', '9.99', '12.75', '1.97', '9.08', '11.44', '3.98', '5.03', '0.79', '3.25', '18.25', '4.81', '4.69', '9.4', '40.9', '6.9', '2.53', '6.1', '0.86', '5.84', '44.5', '2.97', '10.84', '18.9', '11.7', '40.62', '3.52', '13.1', '55.6', '4.45', '5.06', '3.85', '12.16', '7.9', '13.2', '13.19', '2.7', '8.89', '4.08', '55.25', '6.04', '8.02', '4.31', '11.49', '19.9', '2.1', '3.04', '4.23', '3.1', '11.12', '43', '4.17', '36.72', '17.41', '18.69', '8.76', '24.42', '4.12', '27.18', '9.23', '4.59', '3.84', '16.65', '17.35', '13.01', '14.96', '7.15', '41.51', '40.21', '44.12', '13.77', '24.21', '2.81', '14.77', '40.03', '170.24', '2.18', '34.31', '13.95', '8.41', '8.61', '26.45', '7.41', '40.07', '17.63', '9.98', '38.93', '15.13', '2.43', '172.37', '171.65', '4.07', '53.26', '15.74', '37.03', '19.42', '9.15', '9.86', '39.81', '19.35', '119.64', '45.78', '11.91', '4.63', '39.28', '13.72', '3.92', '24.31', '1.99', '8.91', '7.53', '6.28', '171.01', '47.97', '121.71', '8.88', '14.54', '116.78', '43.98', '39.01', '34.76', '15.72', '18.78', '16.57', '7.08', '0.74', '41.76', '105.9', '105.23', '34.94', '13.12', '3.63', '21.39', '30.82', '29.8', '11.39', '6.98', '10.05', '148.54', '35.96', '30.35', '5.72', '30.77', '21.87', '5.21', '29.43', '11.51', '23.64', '21.51', '7.49', '30.98', '9.89', '8.09', '146.63', '57.02', '12.23', '24.65', '8.34', '9.01', '9.32', '139.71', '3.28', '27.9', '22.67', '29.86', '5.42', '10.48', '11.17', '9.07', '36.62', '142.41', '5.04', '53.3', '103.7', '32.96', '19.81', '8.71', '20.07', '7.56', '9.13', '106.96', '36.58', '35.6', '37.15', '9.47', '11.07', '164.14', '9.6', '112.61', '37.8', '42.79', '35.27', '6.19', '55.57', '11.52', '42.45', '22.11', '6.39', '1.53', '2.36', '164.59', '33.57', '25.48', '39.67', '4.82', '25.63', '15.32', '167.52', '13.16', '31.96', '26.68', '32.52', '9.42', '29.53', '4.54', '13.27', '6.99', '150.2', '55.9', '31.05', '12.09', '108.28', '36.76', '22.33', '4.74', '4.02', '14.47', '23.65', '11.18', '1.42', '2.65', '12.94', '32.16', '110.09', '37.71', '16.84', '82.45', '45.17', '67.98', '30.02', '42.87', '46.33', '60.53', '27.94', '27.85', '21.89', '5.55', '86.48', '30.18', '42.2', '56.27', '60.88', '21.07', '19.86', '27.82', '5. ...
# ------------------------------
# 🔍 العمود: 【usdprice】
#    - قيم نادرة (ممكن تكون غلطات): ['2.37', '7.37', '0.087', '8.51', '0.095', '0.098', '8.79', '8.65', '6.3', '8.92', '7.86', '2.77', '8.32', '5.34', '7.78', '5.97', '8.58', '6.93', '5.46', '2.81', '2.27', '6.92', '7.03', '2.59', '9.67', '6.9', '2.36', '6.87', '0.92', '1.27', '0.83', '2.61', '2.29', '2.25', '6.09', '9.92', '2.66', '5.86', '0.17', '1.97', '2.82', '8.56', '5.79', '5.88', '8.59', '6.18', '6.99', '2.58', '2.16', '2.67', '5.51', '5.44', '8.19', '2.51', '2.45', '8.37', '2.24', '5.49', '2.07', '8.54', '6.85', '8.41', '8.5', '9.1', '5.47', '5.52', '4.7', '6.58', '6.7', '0.19', '8.62', '2.94', '8.55', '0.16', '8.43', '2.38', '4.69', '2.57', '2.65', '5.02', '0.096', '8.42', '6.95', '8.39', '5.55', '6.94', '6.91', '4.71', '9.58', '8.77', '6.84', '6.74', '8.72', '8.64', '9.45', '9.32', '5.64', '6.61', '0.099', '5.78', '9.08', '2.41', '5.53', '9', '8.63', '6.17', '8.85', '2.3', '6.11', '5.45', '8.04', '7.96', '8.28', '5.43', '9.03', '5.94', '6.68', '8.31', '5.41', '8.35', '0.077', '6.37', '7.31', '9.19', '9.14', '8.93', '3.15', '9.43', '9.52', '2.79', '6.62', '8.98', '3.06', '8.6', '6.02', '8.15', '2.8', '5.48', '2.72', '7.95', '8.67', '8.4', '2.74', '9.05', '2.6', '6.26', '3.12', '3.28', '9.15', '0.076', '2.26', '8.81', '9.33', '6.1', '2.28', '2.52', '9.6', '1.07', '9.64', '9.21', '6.27', '9.07', '9.24', '6.39', '9.23', '6.59', '9.61', '2.35', '10.02', '10.03', '2.2', '6.97', '3.03', '7.17', '6.05', '7.94', '6.12', '2.44', '3.26', '7.97', '11.42', '3.51', '10.21', '3.13', '7.09', '10.29', '3.27', '3.49', '3.58', '11.49', '7.82', '7.06', '4.91', '1.09', '0.064', '4.34', '0.072', '4.5', '7.42', '7.04', '4.99', '7.46', '3', '11.67', '6.32', '8.68', '8.29', '5.82', '2.53', '5.96', '2.92', '6.13', '6.29', '6.45', '2.91', '9.39', '2.9', '2.68', '6.55', '2.14', '8.89', '2.78', '6.38', '7.98', '6.04', '6', '6.49', '1.02']
# ------------------------------

# %% [markdown]
# ### step:4]- Exploratory Data Analysis(EDA)

# %%
#descriptive statistics
df.describe().T
# Out:
#              count unique                 top  freq
# date          2490    176          2021-02-15    30
# category      2490      7  cereals and tubers   553
# commodity     2490     31             Lentils   147
# commodity_id  2490     31                 108   147
# unit          2490      6                  KG  1981
# price         2490   1320                23.5    19
# usdprice      2490    446                0.62    42

# %%
df.describe(include="object").T
# Out:
#              count unique                 top  freq
# date          2490    176          2021-02-15    30
# category      2490      7  cereals and tubers   553
# commodity     2490     31             Lentils   147
# commodity_id  2490     31                 108   147
# unit          2490      6                  KG  1981
# price         2490   1320                23.5    19
# usdprice      2490    446                0.62    42

# %%
df.select_dtypes(include="number").columns
# Out:
# Index([], dtype='object')

# %%
# df_main = pd.read_csv('main_data.csv')

# df_nutrients = pd.read_csv('nutrients_data.csv')

# %%
# merged_df = pd.merge(df_main, df_nutrients, on='commodity', how='left')


# print(merged_df.head())

# %%
df.to_csv('final food prices data.csv', index=False)
